# %% [markdown]
# # case2-dealing with unbalanced data

# %%
import numpy as np
import pandas as pd
from sklearn.utils import resample

# %%
data=pd.read_csv("/Users/wenqi/Desktop/case2/Training_Data.csv")

# %%
data
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
data.loc[data['Risk_Flag']==0].shape[0] / data.loc[data['Risk_Flag']==1].shape[0]
# Out:
# 7.130081300813008

# %%
data.loc[data['Risk_Flag']==0].shape[0]
# Out:
# 221004

# %%
data.loc[data['Risk_Flag']==1].shape[0]
# Out:
# 30996

# %%
y = data['Risk_Flag']

# %%
X = data.drop(['Risk_Flag'],axis=1)

# %%
X
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
from sklearn.utils import resample


df_majority = data[data.Risk_Flag==0]
df_minority = data[data.Risk_Flag==1]

# %% [markdown]
# ## Downsampling

# %%
# Downsample majority class
df_majority_downsampled = resample(df_majority, 
                                 replace=False,    # sample without replacement
                                 n_samples=len(df_minority),  # to match minority class
                                 random_state=1234) # reproducible results
 
# Combine minority class with downsampled majority class
df_downsampled = pd.concat([df_majority_downsampled, df_minority])
 
# Display new class counts
df_downsampled.Risk_Flag.value_counts()
# Out:
# 0    30996
# 1    30996
# Name: Risk_Flag, dtype: int64

# %%
df_downsampled
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 64889    64890  5644262   60           7         single          rented
# 219602  219603  2025217   54           6         single          rented
# 193692  193693  7256900   55           9         single          rented
# 5086      5087  2047235   61           1         single          rented
# 47930    47931  2730986   35          10         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251973  251974  1244622   35          15         single          rented
# 251977  251978  1330613   63          19         single          rented
# 251981  251982  1796713   47           2         single          rented
# 251982  251983  3182290   52           2         single          rented
# 251993  251994  8141027   60          10         single          rented
#
#        Car_Ownership      Profession             CITY           STATE  \
# ...

# %% [markdown]
# ## Upsampling

# %%
df_minority_upsampled = resample(df_minority, 
                                 replace=True,     # sample with replacement
                                 n_samples=len(df_majority),    # to match majority class
                                 random_state=1234) # reproducible results
# Combine majority class with upsampled minority class
df_upsampled = pd.concat([df_majority, df_minority_upsampled])
 
# Display new class counts
df_upsampled.Risk_Flag.value_counts()
# Out:
# 0    221004
# 1    221004
# Name: Risk_Flag, dtype: int64

# %% [markdown]
# ## SMOTETomek

# %%
from imblearn.over_sampling import RandomOverSampler
os =  RandomOverSampler()

# %%
X_train_res, y_train_res = os.fit_resample(X, y)
X_train_res.shape,y_train_res.shape
# Out:
# ((442008, 12), (442008,))

# %%
y_train_res.to_frame().groupby('Risk_Flag').size()
# Out:
# Risk_Flag
# 0    221004
# 1    221004
# dtype: int64
