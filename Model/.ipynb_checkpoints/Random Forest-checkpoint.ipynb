# %%
import numpy as np
import pandas as pd
import seaborn as sn
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.cluster import KMeans

# %%
#Train_data=pd.read_csv('data/Training Data.csv')
#Test_x=pd.read_csv('data/Test Data.csv')
#Test_y=pd.read_csv('data/Sample Prediction Dataset.csv')

# %%
Train_data=pd.read_csv('../Data/train_data.csv')
Test_x=pd.read_csv('../Data/test_data.csv')
#Test_y=pd.read_csv('../Data/')

# %%
Train_data
# Out:
#             Id   Income  Age  Experience Married/Single House_Ownership  \
# 0            1  1303834   23           3         single          rented
# 1            2  7574516   40          10         single          rented
# 2            3  3991815   66           4        married          rented
# 3            4  6256451   41           2         single          rented
# 4            5  5768871   47          11         single          rented
# ...        ...      ...  ...         ...            ...             ...
# 251995  251996  8154883   43          13         single          rented
# 251996  251997  2843572   26          10         single          rented
# 251997  251998  4522448   46           7         single          rented
# 251998  251999  6507128   45           0         single          rented
# 251999  252000  9070230   70          17         single          rented
#
#        Car_Ownership           Profession                 CITY  \
# ...

# %%
Train_data.loc[(Train_data['Married/Single'] == 'single'),"Married/Single"] = 0
Train_data.loc[(Train_data['Married/Single'] == 'married'),"Married/Single"] = 1
Train_data["Married/Single"] = Train_data["Married/Single"].astype(str).astype(int)
Train_data.loc[(Train_data['Car_Ownership'] == 'no'),"Car_Ownership"] = 0
Train_data.loc[(Train_data['Car_Ownership'] == 'yes'),"Car_Ownership"] = 1
Train_data["Car_Ownership"] = Train_data["Car_Ownership"].astype(str).astype(int)

# %%
Train_data.dtypes
# Out:
# Id                    int64
# Income                int64
# Age                   int64
# Experience            int64
# Married/Single        int32
# House_Ownership      object
# Car_Ownership         int32
# Profession           object
# CITY                 object
# STATE                object
# CURRENT_JOB_YRS       int64
# CURRENT_HOUSE_YRS     int64
# Risk_Flag             int64
# dtype: object

# %%
corr=Train_data[["Married/Single","Car_Ownership","Risk_Flag"]].corr()

# %%
corr
# Out:
#                 Married/Single  Car_Ownership  Risk_Flag
# Married/Single        1.000000      -0.001206  -0.021092
# Car_Ownership        -0.001206       1.000000  -0.024036
# Risk_Flag            -0.021092      -0.024036   1.000000

# %%
sn.heatmap(corr, annot=True)
plt.show()

# %%
df=Train_data[["Age","Experience","Married/Single","Car_Ownership","CURRENT_JOB_YRS","CURRENT_HOUSE_YRS","Risk_Flag"]]
df
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 0        23           3               0              0                3
# 1        40          10               0              0                9
# 2        66           4               1              0                4
# 3        41           2               0              1                2
# 4        47          11               0              0                3
# ...     ...         ...             ...            ...              ...
# 251995   43          13               0              0                6
# 251996   26          10               0              0                6
# 251997   46           7               0              0                7
# 251998   45           0               0              0                0
# 251999   70          17               0              0                7
#
#         CURRENT_HOUSE_YRS  Risk_Flag
# 0                      13          0
# ...

# %%
# Count the occurrences of fraud and no fraud and print them
occ = df['Risk_Flag'].value_counts()
occ
# Out:
# 0    221004
# 1     30996
# Name: Risk_Flag, dtype: int64

# %%
plt.bar(range(len(occ)),occ)
plt.xticks([0, 1], ["negative", 'positive'],fontproperties='SimHei')
plt.show()

# %%
# Print the ratio of fraud cases
ratio_cases = occ/len(df.index)
print(f'Ratio of defaulter cases: {ratio_cases[1]}\nRatio of non-defaulter cases: {ratio_cases[0]}')
# Out:
# Ratio of defaulter cases: 0.123
# Ratio of non-defaulter cases: 0.877

# %%
X = df.iloc[:, 0:6].values
X
# Out:
# array([[23,  3,  0,  0,  3, 13],
#        [40, 10,  0,  0,  9, 13],
#        [66,  4,  1,  0,  4, 10],
#        ...,
#        [46,  7,  0,  0,  7, 12],
#        [45,  0,  0,  0,  0, 10],
#        [70, 17,  0,  0,  7, 11]], dtype=int64)

# %%
kmeans = KMeans(n_clusters = 2).fit_predict(X)
print(kmeans)
# Out:
# [1 1 0 ... 1 1 0]

# %%
import matplotlib.pyplot as plt

# %%
#filter rows of original data
filtered_label0 = df[kmeans == 0]
 
filtered_label1 = df[kmeans == 1]
 
#Plotting the results
#plt.scatter(filtered_label2[:,0] , filtered_label2[:,1] , color = 'red')
#plt.scatter(filtered_label8[:,0] , filtered_label8[:,1] , color = 'black')
#plt.show()

# %%
filtered_label0
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 2        66           4               1              0                4
# 5        64           0               0              0                0
# 6        58          14               1              0                8
# 10       78           7               0              0                7
# 13       57          12               0              0                8
# ...     ...         ...             ...            ...              ...
# 251988   68           7               0              0                7
# 251990   68           4               0              0                4
# 251992   57           7               1              0                4
# 251993   60          10               0              0                9
# 251999   70          17               0              0                7
#
#         CURRENT_HOUSE_YRS  Risk_Flag
# 2                      10          0
# ...

# %%
filtered_label1
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 0        23           3               0              0                3
# 1        40          10               0              0                9
# 3        41           2               0              1                2
# 4        47          11               0              0                3
# 7        33           2               0              0                2
# ...     ...         ...             ...            ...              ...
# 251994   27           8               0              0                8
# 251995   43          13               0              0                6
# 251996   26          10               0              0                6
# 251997   46           7               0              0                7
# 251998   45           0               0              0                0
#
#         CURRENT_HOUSE_YRS  Risk_Flag
# 0                      13          0
# ...

# %%
df
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 0        23           3               0              0                3
# 1        40          10               0              0                9
# 2        66           4               1              0                4
# 3        41           2               0              1                2
# 4        47          11               0              0                3
# ...     ...         ...             ...            ...              ...
# 251995   43          13               0              0                6
# 251996   26          10               0              0                6
# 251997   46           7               0              0                7
# 251998   45           0               0              0                0
# 251999   70          17               0              0                7
#
#         CURRENT_HOUSE_YRS  Risk_Flag
# 0                      13          0
# ...

# %%
X = df.iloc[:,0:6]
X
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 0        23           3               0              0                3
# 1        40          10               0              0                9
# 2        66           4               1              0                4
# 3        41           2               0              1                2
# 4        47          11               0              0                3
# ...     ...         ...             ...            ...              ...
# 251995   43          13               0              0                6
# 251996   26          10               0              0                6
# 251997   46           7               0              0                7
# 251998   45           0               0              0                0
# 251999   70          17               0              0                7
#
#         CURRENT_HOUSE_YRS
# 0                      13
# 1                      13
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

rng = np.random.RandomState(42)

# Generate train data
X = df.iloc[:,0:6]
y=df.iloc[:,6]
X_train, X_test, Y_train, Y_test =train_test_split(X, y, test_size=0.3)

# %%
X_train
# Out:
#         Age  Experience  Married/Single  Car_Ownership  CURRENT_JOB_YRS  \
# 144842   51          19               0              0                6
# 40489    31           2               0              0                2
# 76789    44           5               0              0                5
# 8455     75          12               0              0               12
# 199366   41          20               0              1                7
# ...     ...         ...             ...            ...              ...
# 167974   50           0               0              0                0
# 118590   66           1               0              1                1
# 159428   72          19               0              0                4
# 41385    47          19               0              1               12
# 186983   75          17               0              0               11
#
#         CURRENT_HOUSE_YRS
# 144842                 14
# 40489                  10
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(X_train,Y_train)
# Out:
# RandomForestClassifier()

# %%
model.score(X_test,Y_test)
# Out:
# 0.8873280423280423

# %%
Y_predict=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score
print(f'Accuracy={accuracy_score(Y_test,Y_predict):.2f}\nRecall={recall_score(Y_test,Y_predict):.2f}\n')
# Out:
# Accuracy=0.89
# Recall=0.47

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(Y_test,Y_predict)

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm,annot=True,cmap="Blues")
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %% [markdown]
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
LogReg=LogisticRegression()
LogReg.fit(X_train,Y_train)
# Out:
# LogisticRegression()

# %%
LogReg.score(X_test,Y_test)
# Out:
# 0.878531746031746

# %%
Y_predict_log=LogReg.predict(X_test)
print(f'Accuracy={accuracy_score(Y_test,Y_predict_log):.2f}\nRecall={recall_score(Y_test,Y_predict_log):.2f}\n')
# Out:
# Accuracy=0.88
# Recall=0.00

# %%
cm_log=confusion_matrix(Y_test,Y_predict_log)
plt.figure(figsize=(10,7))
sns.heatmap(cm_log,annot=True,cmap="Blues")
plt.xlabel('Predict')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')
